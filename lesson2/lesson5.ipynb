# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1679, 0.1768, 0.0887],
#         [0.8488, 0.3622, 0.3816],
#         [0.8645, 0.4103, 0.6980],
#         [0.7865, 0.0541, 0.7011],
#         [0.6648, 0.6191, 0.4441]])

# %%
torch.cuda.is_available()
# Out:
# True
